# %% [markdown]
# # Microlitografia
#
# ## Giorno 1: Preparazione del negativo del master
# Abbiamo fatto una mixture con 9g di elastomero e 1g di coso. Abbiamo girato come il risotto per 1 minuto (20s a testa) e abbiamo messo nella camera a leggero vuoto ( $\sim -1$ bar) per eliminare le bolle d'aria all'interno della mixture. Una volta tolte ( circa mezz'ora nella camera) si deposita un film elastomerico sul master e si cuoce su piastra elettrica a 140° per 10 minuti. Una volta raffreddato, si taglia con il bisturi l'elastomero e si posiziona su un vetrino da microscopio opportunamente pulito. Si osserva al microscopio e si vede frecce, quadrati, triangoli. Niente di utile.

# %%
# Codice per visualizzazione immagine e misura del rapporto pixel/micron
from PIL import Image

img = Image.open('/Users/valeriofrancopecchia/Desktop/Fisica/LabMateriaGit/Microlitografia/g7-metro-40x8781.jpg')

img.show()

print(img.format, img.size, img.mode)
# Out:
# JPEG (2048, 1536) RGB

# %% [markdown]
# Utilizzando il codice sopra si stima il rapporto pixel micron per i vari ingrandimenti. Si misura una tacca corrispondente a $50\mu\text{m}$
#
# | L | 4X | 10X | 20X | 40X |
# |:---:|:---:|:---:|:---:|:---:|
# | Pixel | $23 \pm 1$ | $56 \pm 1$ | $107 \pm 1$| $225 \pm 1$|
# |Pixel/micron | 0.46| 1.12|2.14|4.5|
